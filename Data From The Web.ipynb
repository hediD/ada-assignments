# %% [markdown]
# # Homework: Data from the Web

# %%
# setup
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn'
import requests
from bs4 import BeautifulSoup
import html5lib
import scipy.stats as stats
import matplotlib.pyplot as plt
import math

# %% [markdown]
# #### Examination of IS Academia

# %% [markdown]
# We want to examine the IS-Academia page to see what kind of information to pass

# %%
# Send an URL request to see the prameters we will need later for getting the data
r = requests.get('http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.filter?ww_b_list=1&ww_i_reportmodel=133685247&ww_c_langue=&ww_i_reportModelXsl=133685270&zz_x_UNITE_ACAD=Informatique&ww_x_UNITE_ACAD=249847&zz_x_PERIODE_ACAD=2007-2008&ww_x_PERIODE_ACAD=978181&zz_x_PERIODE_PEDAGO=Bachelor+semestre+1&ww_x_PERIODE_PEDAGO=249108&zz_x_HIVERETE=Semestre+d%27automne&ww_x_HIVERETE=2936286&dummy=ok')


# get the data of the HTML file
soup = BeautifulSoup(r.text, 'html.parser')


# create the Series (like a dictionnary) that will give us later the code for each parameter that will allow us to get the data
keys = []
values = []
for test in soup.find_all('option') :
    if(test.contents) == [] :
        continue
    keys.append(test.contents[0])
    values.append(test['value'])



encode = pd.Series(data = values, index = keys)
encode
# Out:
# Architecture                                     942293
# Chimie et génie chimique                         246696
# Cours de mathématiques spéciales                 943282
# EME (EPFL Middle East)                        637841336
# Génie civil                                      942623
# Génie mécanique                                  944263
# Génie électrique et électronique                 943936
# Humanités digitales                          2054839157
# Informatique                                     249847
# Ingénierie financière                         120623110
# Management de la technologie                     946882
# Mathématiques                                    944590
# Microtechnique                                   945244
# Physique                                         945571
# Science et génie des matériaux                   944917
# Sciences et ingénierie de l'environnement        942953
# Sciences et technologies du vivant               945901
# Section FCUE                                 1574548993
# Systèmes de communication                        946228
# 2016-2017                                     355925344
# 2015-2016                                     213638028
# 2014-2015                                     213637922
# 2013-2014                                     213637754
# 2012-2013                                     123456101
# 2011-2012                                     123455150
# 2010-2011                                      39486325
# 2009-2010                                        978195
# 2008-2009                                        978187
# 2007-2008                                        978181
# Bachelor semestre 1                              249108
# Bachelor semestre 2                              249114
# Bachelor semestre 3                              942155
# Bachelor semestre 4                              942163
# Bachelor semestre 5                              942120
# Bachelor semestre 5b                            2226768
# Bachelor semestre 6                              942175
# Bachelor semestre 6b                            2226785
# Master semestre 1                               2230106
# Master semestre 2                                942192
# Master semestre 3                               2230128
# Master semestre 4                               2230140
# Mineur semestre 1                               2335667
# Mineur semestre 2                               2335676
# Mise à niveau                                2063602308
# Projet Master automne                            249127
# Projet Master printemps                         3781783
# Semestre automne                                 953159
# Semestre printemps                              2754553
# Stage automne 3ème année                         953137
# Stage automne 4ème année                        2226616
# Stage printemps 3ème année                       983606
# Stage printemps 4ème année                      2226626
# Stage printemps master                          2227132
# Semestre d'automne                              2936286
# Semestre de printemps                           2936295
# dtype: object

# %% [markdown]
# #### Examination of one table

# %% [markdown]
# For examination we extract the html table for bachelor students in their first semester in 2007-2008

# %%
# dict to pass the right values to the form
bach0708 = {'ww_x_GPS':'-1', 'ww_i_reportmodel':'133685247','ww_i_reportModelXsl':'133685270','ww_x_UNITE_ACAD':'249847', 'ww_x_PERIODE_ACAD':'978181', 'ww_x_PERIODE_PEDAGO':'249108', 'ww_x_HIVERETE':'2936286' }
r = requests.get('http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.html', params=bach0708)
soup = BeautifulSoup(r.text, 'html.parser')

# %%
# we examine the table (we commented it because it take too much place in the document)
#soup.find_all('table')

# %%
# we examine the headers of the table
soup.find_all('th')
# Out:
# [<th colspan="12"><font color="black">Informatique, 2007-2008, Bachelor semestre 1</font>
#   (90 ét.)
#      </th>,
#  <th>Civilité</th>,
#  <th>Nom Prénom</th>,
#  <th>Orientation Bachelor</th>,
#  <th>Orientation Master</th>,
#  <th>Spécialisation</th>,
#  <th>Filière opt.</th>,
#  <th>Mineur</th>,
#  <th>Statut</th>,
#  <th>Type Echange</th>,
#  <th>Ecole Echange</th>,
#  <th>No Sciper</th>]

# %% [markdown]
# ### Exercise 1 : Bachelor

# %% [markdown]
# Download all public data from http://isa.epfl.ch/imoniteur_ISAP/%21gedpublicreports.htm?ww_i_reportmodel=133685247 for Informatiques section bachelor students since 2007.

# %% [markdown]
# #### Bachelor records

# %% [markdown]
# Now that we have studied some particular cases to see how is encoded the data in HTML we can code more general methods

# %% [markdown]
# We define two methods "tosoup" that takes the pedagocic period as parameter and returns a parsed soup object, and "bachelortoframe" that takes a soup object as parameter and returns a data frame with student number, name, sex and year.

# %%
# takes code pedagogic period as parameter, returns the parsed soup object
def tosoup(periode_pedago):
    bach = {'ww_x_GPS':'-1', 'ww_i_reportmodel':'133685247','ww_i_reportModelXsl':'133685270','ww_x_UNITE_ACAD':encode['Informatique'], 'ww_x_PERIODE_ACAD':'', 'ww_x_PERIODE_PEDAGO':periode_pedago, 'ww_x_HIVERETE':'' }
    r = requests.get('http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.html', params=bach)
    soup = BeautifulSoup(r.text, 'html.parser')
    return soup

# %%
# takes a soup object as parameter and returns a data frame with all data that is linked to the pedagogic period of the soup parameter
def bachelortoframe(soup):
    
    # create headers for the data frame
    headers = soup.find_all('th')
    H = [h.text.strip() for h in headers]

    #remove the extra column with the table name "Informatique ..." and the repetitions of the header
    del H[0] 
    del H[11:len(H)]

    # find all rows
    datatable_rows = soup.find_all('tr')
    # iterate the data in td cells to an array
    # iterate the year data from the header to an year array
    data = []
    year = []
    for row in datatable_rows:
        # if row is a header and has a tag font it has information about the table: section, period and year
        if (row.th != None and row.th.font):
            # select the year from the header 
            actual_year = row.th.font.contents[0].split(",")[1]
        # if row is not a header find all tds    
        elif (row.th == None and int(actual_year.split("-")[0])>=2007):
            td = row.find_all('td')      
            rowvals = {}
            for i in range(len(H)):
                year.append(actual_year)
                rowvals[H[i]] = td[i].get_text()
                data.append(rowvals)
               
    df = pd.DataFrame(data, columns=H)
    # keep interesting columns     
    df= df[['No Sciper', 'Civilité', 'Nom Prénom']]
    # add year information
    df ['year'] = year
    
    return df

# %%
# take all bachelor semester 1 registrations and put them in a dataframe
bachelor1 = bachelortoframe(tosoup(encode['Bachelor semestre 1']))

# we want to keep only one value for bachelor semester 1 which should be the first entry 
bachelor1.drop_duplicates(subset = 'No Sciper' ,keep = 'first', inplace = True)

# we set the sciper number as the index
bachelor1 = bachelor1.set_index('No Sciper')

# add the starting year
start_year = [year.split("-")[0] for year in bachelor1.year]
bachelor1['Start year'] = start_year

# rename year column to Bachelor Semester 1
bachelor1.rename(columns={'year': 'Bachelor semester 1'}, inplace=True)

bachelor1
# Out:
#            Civilité                                         Nom Prénom  \
# No Sciper
# 169569     Monsieur                                  Arévalo Christian
# 174905     Monsieur                                    Aubelle Flavien
# 173922     Monsieur                                      Badoud Morgan
# 179406     Monsieur                                 Baeriswyl Jonathan
# 179428     Monsieur                                    Barroco Michael
# 179324     Monsieur                                     Belfis Nicolas
# 174597     Monsieur                                  Beliaev Stanislav
# 179449     Monsieur                              Bindschaedler Vincent
# 178553     Monsieur                                 Bloch Marc-Olivier
# 179426     Monsieur                                         Bloch Remi
# 178271     Monsieur                             Boéchat Marc-Alexandre
# 182433     Monsieur                                     Böhler Michael
# 180731     Monsieur                               Bricola Jean-Charles
# 171619     Monsieur                               Buchschacher Nicolas
# 179837     Monsieur                                       Caloz Daniel
# 179157     Monsieur                                     Calvert Thomas
# 179864     Monsieur                                   Cambazard Thomas
# 174590     Monsieur                                Camenzind Guillaume
# 178843     Monsieur                                     Cattin Nicolas
# 178711     Monsieur                                       Cino Emanuel
# 178786     Monsieur                                       Coiro Andrea
# 179567     Monsieur                                  Collavini Gregory
# 176282     Monsieur                                     Corbat Nicolas
# 178656     Monsieur                                  Curreli Alexandre
# 181445     Monsieur                                     Custovic Alain
# 178718     Monsieur                                   Dal Mas Gianluca
# 175466     Monsieur                                  Decorvet Grégoire
# 173882     Monsieur                                  Dettwiler Fabrice
# 181612       Madame                                  Ej-Jennane Jihane
# 181232     Monsieur                                     Epiney Vincent
# ...             ...                                                ...
# 265553     Monsieur                                     Simic Nicholas
# 259268     Monsieur                                    Simik Alexandre
# 271030     Monsieur                                     Singer Florian
# 272432     Monsieur                                      Strauss Lucas
# 272430     Monsieur                                      Sürmely Lucas
# 270497     Monsieur                                Tappy Dylan Maurice
# 276507     Monsieur  Thierry D'Argenlieu Nicolas Alain Alexandre Marie
# 258572     Monsieur              Thouvenin Alexandre Lawrence Emmanuel
# 273018       Madame                           Thurnherr Gabrielle Leck
# 272765     Monsieur                          Tomasini Cédric Alexandre
# 273578     Monsieur                                        Topcic Ivan
# 261549       Madame                                 Uzuner Nazli Deniz
# 266682       Madame                               Van Kommer Naïla May
# 269700     Monsieur                                   Veneziano Andrea
# 272284     Monsieur                            Verdet Matthieu Flavien
# 270055     Monsieur                       Vialar Louis Michel Jean-Luc
# 271901     Monsieur                                 Vignon Arthur Carl
# 271183     Monsieur                                     Vilpert Arnaud
# 269637     Monsieur                        Vray Guillaume Marc Georges
# 271228       Madame                                         Weber Elsa
# 260589     Monsieur                                        Wicky Simon
# 269583     Monsieur                                      Widmer Ulysse
# 276016     Monsieur                            Wilders Eric Bruno John
# 274240     Monsieur                                    Witschard Loris
# 261781       Madame                              Wonjamouna Rosy-Laure
# 268785     Monsieur                        Youssefi Dahn Samuel Darius
# 276323     Monsieur                         Zeller Corentin Luc Claude
# 257393     Monsieur                                      Zghonda Jalel
# 250422     Monsieur                                       Zhou Jianhan
# 269845     Monsieur                                Zumbach Yves Arnaud
#
#           Bachelor semester 1 Start year
# No Sciper
# 169569              2007-2008       2007
# 174905              2007-2008       2007
# 173922              2007-2008       2007
# 179406              2007-2008       2007
# 179428              2007-2008       2007
# 179324              2007-2008       2007
# 174597              2007-2008       2007
# 179449              2007-2008       2007
# 178553              2007-2008       2007
# 179426              2007-2008       2007
# 178271              2007-2008       2007
# 182433              2007-2008       2007
# 180731              2007-2008       2007
# 171619              2007-2008       2007
# 179837              2007-2008       2007
# 179157              2007-2008       2007
# 179864              2007-2008       2007
# 174590              2007-2008       2007
# 178843              2007-2008       2007
# 178711              2007-2008       2007
# 178786              2007-2008       2007
# 179567              2007-2008       2007
# 176282              2007-2008       2007
# 178656              2007-2008       2007
# 181445              2007-2008       2007
# 178718              2007-2008       2007
# 175466              2007-2008       2007
# 173882              2007-2008       2007
# 181612              2007-2008       2007
# 181232              2007-2008       2007
# ...                       ...        ...
# 265553              2016-2017       2016
# 259268              2016-2017       2016
# 271030              2016-2017       2016
# 272432              2016-2017       2016
# 272430              2016-2017       2016
# 270497              2016-2017       2016
# 276507              2016-2017       2016
# 258572              2016-2017       2016
# 273018              2016-2017       2016
# 272765              2016-2017       2016
# 273578              2016-2017       2016
# 261549              2016-2017       2016
# 266682              2016-2017       2016
# 269700              2016-2017       2016
# 272284              2016-2017       2016
# 270055              2016-2017       2016
# 271901              2016-2017       2016
# 271183              2016-2017       2016
# 269637              2016-2017       2016
# 271228              2016-2017       2016
# 260589              2016-2017       2016
# 269583              2016-2017       2016
# 276016              2016-2017       2016
# 274240              2016-2017       2016
# 261781              2016-2017       2016
# 268785              2016-2017       2016
# 276323              2016-2017       2016
# 257393              2016-2017       2016
# 250422              2016-2017       2016
# 269845              2016-2017       2016
#
# [1324 rows x 4 columns]

# %%
# take all bachelor semester 6 registrations and put them in a dataframe
bachelor6 = bachelortoframe(tosoup(encode['Bachelor semestre 6']))

# we want to keep only one value for bachelor semester 6 which should be the last entry (if the student didn't fail 3rd year)
bachelor6.drop_duplicates(subset = 'No Sciper',keep='last', inplace = True)

# we set the sciper number as the index
bachelor6 = bachelor6.set_index('No Sciper')

# add the Ending year
end_year = [year.split("-")[1] for year in bachelor6.year]
bachelor6['End year'] = end_year

# rename year column to Bachelor Semester 6
bachelor6.rename(columns={'year': 'Bachelor semester 6'}, inplace=True)

# we already have name and sex information associated with the student number so we drop those columns
bachelor6 = bachelor6.drop('Civilité', axis=1).drop('Nom Prénom', axis=1)

# %%
bachelor6.head()
# Out:
#           Bachelor semester 6 End year
# No Sciper
# 161634              2007-2008     2008
# 170451              2007-2008     2008
# 170219              2007-2008     2008
# 153762              2007-2008     2008
# 166548              2007-2008     2008

# %%
# merge the two tables based on the student number that is index
bachelor1_6 = pd.merge(bachelor1, bachelor6, left_index=True, right_index=True)
bachelor1_6.head()
# Out:
#            Civilité              Nom Prénom Bachelor semester 1 Start year  \
# No Sciper
# 169569     Monsieur       Arévalo Christian           2007-2008       2007
# 179449     Monsieur   Bindschaedler Vincent           2007-2008       2007
# 178553     Monsieur      Bloch Marc-Olivier           2007-2008       2007
# 178271     Monsieur  Boéchat Marc-Alexandre           2007-2008       2007
# 180731     Monsieur    Bricola Jean-Charles           2007-2008       2007
#
#           Bachelor semester 6 End year
# No Sciper
# 169569              2009-2010     2010
# 179449              2009-2010     2010
# 178553              2009-2010     2010
# 178271              2009-2010     2010
# 180731              2009-2010     2010

# %% [markdown]
# ## in case someone repeated semester 5 after their last semester 6

# %%
# take all bachelor semester 5 registrations and put them in a dataframe
bachelor5 = bachelortoframe(tosoup(encode['Bachelor semestre 5']))

# we want to keep only one value for bachelor semester 5 which should be the last entry 
bachelor5.drop_duplicates(subset = 'No Sciper', keep='last', inplace = True)

# we set the sciper number as the index
bachelor5 = bachelor5.set_index('No Sciper')

# add the Bachelor 5 Ending year
end_year = [year.split("-")[1] for year in bachelor5.year]
bachelor5['Bachelor 5 end year'] = end_year

# rename year column to Bachelor Semester 5
bachelor5.rename(columns={'year': 'Bachelor semester 5'}, inplace=True)

# we remove the repeted columns 'civilité' and 'Nom Prénom'
bachelor5 = bachelor5.drop('Civilité', axis=1).drop('Nom Prénom', axis=1)

# %%
bachelor5.head()
# Out:
#           Bachelor semester 5 Bachelor 5 end year
# No Sciper
# 154157              2007-2008                2008
# 160213              2007-2008                2008
# 161634              2007-2008                2008
# 170451              2007-2008                2008
# 170219              2007-2008                2008

# %%
# we merge the merged data frame bachelor 1 and 6 with the extra bachelor 5 data frame
all_bachelor = pd.merge(bachelor1_6, bachelor5, left_index=True, right_index=True)

all_bachelor.head()
# Out:
#            Civilité              Nom Prénom Bachelor semester 1 Start year  \
# No Sciper
# 169569     Monsieur       Arévalo Christian           2007-2008       2007
# 179449     Monsieur   Bindschaedler Vincent           2007-2008       2007
# 178553     Monsieur      Bloch Marc-Olivier           2007-2008       2007
# 178271     Monsieur  Boéchat Marc-Alexandre           2007-2008       2007
# 180731     Monsieur    Bricola Jean-Charles           2007-2008       2007
#
#           Bachelor semester 6 End year Bachelor semester 5 Bachelor 5 end year
# No Sciper
# 169569              2009-2010     2010           2009-2010                2010
# 179449              2009-2010     2010           2009-2010                2010
# 178553              2009-2010     2010           2009-2010                2010
# 178271              2009-2010     2010           2009-2010                2010
# 180731              2009-2010     2010           2009-2010                2010

# %%
# we compare the end year of bachelor 5 and 6, if the end year for bachelor 5 is later than for bachelor 6
# we add 0.5 (years) in a new column "Extra semester, otherwise we add 0

all_bachelor['Extra semester'] = np.where(all_bachelor['Bachelor 5 end year'] > all_bachelor['End year'] , 0.5, 0)
all_bachelor.head(50)
# Out:
#            Civilité                         Nom Prénom Bachelor semester 1  \
# No Sciper
# 169569     Monsieur                  Arévalo Christian           2007-2008
# 179449     Monsieur              Bindschaedler Vincent           2007-2008
# 178553     Monsieur                 Bloch Marc-Olivier           2007-2008
# 178271     Monsieur             Boéchat Marc-Alexandre           2007-2008
# 180731     Monsieur               Bricola Jean-Charles           2007-2008
# 171619     Monsieur               Buchschacher Nicolas           2007-2008
# 178656     Monsieur                  Curreli Alexandre           2007-2008
# 178706       Madame                Falbriard Stéphanie           2007-2008
# 181121     Monsieur                         Frund Loïc           2007-2008
# 180570     Monsieur                       Habfast Paul           2007-2008
# 181248     Monsieur                     Helfer Etienne           2007-2008
# 178433     Monsieur                  Leuenberger Johan           2007-2008
# 181298     Monsieur                       Lütolf Lukas           2007-2008
# 181115     Monsieur  Miraglia Franco de Carvalho Pedro           2007-2008
# 180094     Monsieur                        Mirza Elias           2007-2008
# 181017     Monsieur                      Nötzli Andres           2007-2008
# 179194     Monsieur                      Obrist Damien           2007-2008
# 179988       Madame                    Portmann Joëlle           2007-2008
# 180959     Monsieur                   Restani Stéphane           2007-2008
# 171195     Monsieur                     Richter Arnaud           2007-2008
# 178948     Monsieur                   Schädeli Andreas           2007-2008
# 180241     Monsieur              Sondag Pierre-Antoine           2007-2008
# 180854     Monsieur                    Vautherin Jonas           2007-2008
# 178682     Monsieur                       Zoller Roman           2007-2008
# 184772     Monsieur                      Arnfred Jonas           2008-2009
# 179406     Monsieur                 Baeriswyl Jonathan           2007-2008
# 179428     Monsieur                    Barroco Michael           2007-2008
# 179426     Monsieur                         Bloch Remi           2007-2008
# 185949     Monsieur                   Bourgeois Jérémy           2008-2009
# 179157     Monsieur                     Calvert Thomas           2007-2008
# 184991     Monsieur                   Chablais Michael           2008-2009
# 178711     Monsieur                       Cino Emanuel           2007-2008
# 178786     Monsieur                       Coiro Andrea           2007-2008
# 178287     Monsieur                    Cressier Gilles           2008-2009
# 185952     Monsieur                   Cuony Maximilien           2008-2009
# 178718     Monsieur                   Dal Mas Gianluca           2007-2008
# 185853     Monsieur                       Gardiol Loïc           2008-2009
# 147008     Monsieur                        Good Xavier           2008-2009
# 175379     Monsieur                  Gremion Sébastien           2007-2008
# 178604     Monsieur                    Haefliger Roger           2007-2008
# 175190     Monsieur                    Hanser Valérian           2007-2008
# 185811       Madame                     Heldner Céline           2008-2009
# 169731     Monsieur                     Knecht Mathieu           2007-2008
# 181076     Monsieur                     Martins Acacio           2007-2008
# 186250     Monsieur       Mégard Lomig Corentin Amédée           2008-2009
# 179848     Monsieur                   Moumni Benyounes           2008-2009
# 187169     Monsieur                   Rebert Alexandre           2008-2009
# 186778       Madame                   Rodriguez Oriane           2008-2009
# 185947     Monsieur                Rojanawisut Bastien           2008-2009
# 179703       Madame                    Salvisberg Véra           2008-2009
#
#           Start year Bachelor semester 6 End year Bachelor semester 5  \
# No Sciper
# 169569          2007           2009-2010     2010           2009-2010
# 179449          2007           2009-2010     2010           2009-2010
# 178553          2007           2009-2010     2010           2009-2010
# 178271          2007           2009-2010     2010           2009-2010
# 180731          2007           2009-2010     2010           2009-2010
# 171619          2007           2009-2010     2010           2009-2010
# 178656          2007           2009-2010     2010           2009-2010
# 178706          2007           2009-2010     2010           2009-2010
# 181121          2007           2009-2010     2010           2009-2010
# 180570          2007           2009-2010     2010           2009-2010
# 181248          2007           2009-2010     2010           2009-2010
# 178433          2007           2009-2010     2010           2009-2010
# 181298          2007           2009-2010     2010           2009-2010
# 181115          2007           2009-2010     2010           2009-2010
# 180094          2007           2009-2010     2010           2009-2010
# 181017          2007           2009-2010     2010           2009-2010
# 179194          2007           2009-2010     2010           2009-2010
# 179988          2007           2009-2010     2010           2009-2010
# 180959          2007           2009-2010     2010           2009-2010
# 171195          2007           2009-2010     2010           2009-2010
# 178948          2007           2009-2010     2010           2009-2010
# 180241          2007           2009-2010     2010           2009-2010
# 180854          2007           2009-2010     2010           2009-2010
# 178682          2007           2009-2010     2010           2009-2010
# 184772          2008           2010-2011     2011           2010-2011
# 179406          2007           2010-2011     2011           2010-2011
# 179428          2007           2010-2011     2011           2010-2011
# 179426          2007           2010-2011     2011           2010-2011
# 185949          2008           2010-2011     2011           2010-2011
# 179157          2007           2010-2011     2011           2010-2011
# 184991          2008           2010-2011     2011           2010-2011
# 178711          2007           2010-2011     2011           2010-2011
# 178786          2007           2009-2010     2010           2010-2011
# 178287          2008           2010-2011     2011           2010-2011
# 185952          2008           2010-2011     2011           2010-2011
# 178718          2007           2010-2011     2011           2010-2011
# 185853          2008           2010-2011     2011           2010-2011
# 147008          2008           2010-2011     2011           2010-2011
# 175379          2007           2010-2011     2011           2010-2011
# 178604          2007           2010-2011     2011           2010-2011
# 175190          2007           2009-2010     2010           2010-2011
# 185811          2008           2010-2011     2011           2010-2011
# 169731          2007           2010-2011     2011           2010-2011
# 181076          2007           2010-2011     2011           2010-2011
# 186250          2008           2010-2011     2011           2010-2011
# 179848          2008           2010-2011     2011           2010-2011
# 187169          2008           2010-2011     2011           2010-2011
# 186778          2008           2010-2011     2011           2010-2011
# 185947          2008           2010-2011     2011           2010-2011
# 179703          2008           2010-2011     2011           2010-2011
#
#           Bachelor 5 end year  Extra semester
# No Sciper
# 169569                   2010             0.0
# 179449                   2010             0.0
# 178553                   2010             0.0
# 178271                   2010             0.0
# 180731                   2010             0.0
# 171619                   2010             0.0
# 178656                   2010             0.0
# 178706                   2010             0.0
# 181121                   2010             0.0
# 180570                   2010             0.0
# 181248                   2010             0.0
# 178433                   2010             0.0
# 181298                   2010             0.0
# 181115                   2010             0.0
# 180094                   2010             0.0
# 181017                   2010             0.0
# 179194                   2010             0.0
# 179988                   2010             0.0
# 180959                   2010             0.0
# 171195                   2010             0.0
# 178948                   2010             0.0
# 180241                   2010             0.0
# 180854                   2010             0.0
# 178682                   2010             0.0
# 184772                   2011             0.0
# 179406                   2011             0.0
# 179428                   2011             0.0
# 179426                   2011             0.0
# 185949                   2011             0.0
# 179157                   2011             0.0
# 184991                   2011             0.0
# 178711                   2011             0.0
# 178786                   2011             0.5
# 178287                   2011             0.0
# 185952                   2011             0.0
# 178718                   2011             0.0
# 185853                   2011             0.0
# 147008                   2011             0.0
# 175379                   2011             0.0
# 178604                   2011             0.0
# 175190                   2011             0.5
# 185811                   2011             0.0
# 169731                   2011             0.0
# 181076                   2011             0.0
# 186250                   2011             0.0
# 179848                   2011             0.0
# 187169                   2011             0.0
# 186778                   2011             0.0
# 185947                   2011             0.0
# 179703                   2011             0.0

# %%
#Convert the dataFrame columns so we can compute the number of year spent by each student in bachelor
all_bachelor_start = [int(i) for i in all_bachelor['Start year']]
all_bachelor_end   = [int(i) for i in all_bachelor['End year']]
all_bachelor_extra =  [float(i) for i in all_bachelor['Extra semester']]

#number of year spent by each student in bachelor
all_bachelor['Stay in years'] = [all_bachelor_end[i] - all_bachelor_start[i] + all_bachelor_extra[i] for i in range(len(all_bachelor))]
all_bachelor
# Out:
#            Civilité                                    Nom Prénom  \
# No Sciper
# 169569     Monsieur                             Arévalo Christian
# 179449     Monsieur                         Bindschaedler Vincent
# 178553     Monsieur                            Bloch Marc-Olivier
# 178271     Monsieur                        Boéchat Marc-Alexandre
# 180731     Monsieur                          Bricola Jean-Charles
# 171619     Monsieur                          Buchschacher Nicolas
# 178656     Monsieur                             Curreli Alexandre
# 178706       Madame                           Falbriard Stéphanie
# 181121     Monsieur                                    Frund Loïc
# 180570     Monsieur                                  Habfast Paul
# 181248     Monsieur                                Helfer Etienne
# 178433     Monsieur                             Leuenberger Johan
# 181298     Monsieur                                  Lütolf Lukas
# 181115     Monsieur             Miraglia Franco de Carvalho Pedro
# 180094     Monsieur                                   Mirza Elias
# 181017     Monsieur                                 Nötzli Andres
# 179194     Monsieur                                 Obrist Damien
# 179988       Madame                               Portmann Joëlle
# 180959     Monsieur                              Restani Stéphane
# 171195     Monsieur                                Richter Arnaud
# 178948     Monsieur                              Schädeli Andreas
# 180241     Monsieur                         Sondag Pierre-Antoine
# 180854     Monsieur                               Vautherin Jonas
# 178682     Monsieur                                  Zoller Roman
# 184772     Monsieur                                 Arnfred Jonas
# 179406     Monsieur                            Baeriswyl Jonathan
# 179428     Monsieur                               Barroco Michael
# 179426     Monsieur                                    Bloch Remi
# 185949     Monsieur                              Bourgeois Jérémy
# 179157     Monsieur                                Calvert Thomas
# ...             ...                                           ...
# 223344     Monsieur                          Forel Duncan Montana
# 228275     Monsieur                           Garin Arnaud Michel
# 223892     Monsieur    Garret Louis-Maxence Thierry Clément Marie
# 217098     Monsieur                          Goullet Boris Melvil
# 214293     Monsieur                Grondier Julien François Nizar
# 246663     Monsieur                           Haefeli Simon Lucas
# 237482     Monsieur                        Haizmann Jean Frédéric
# 213287     Monsieur                        Jacobs Frédéric Jean H
# 245511     Monsieur                                 Lamonato Yves
# 227359     Monsieur             Le Bail-Collet Simon Pierre Yvick
# 250703     Monsieur                      Madillo Raphael Frederic
# 224297     Monsieur                              Maillard Mathias
# 245512     Monsieur                     Massemin Lucas Christophe
# 247855     Monsieur             Mösching Guillaume Edouard Albert
# 227311       Madame          Mollier Lauriane Catherine Emilienne
# 204324     Monsieur                              Nguyen Thai Tinh
# 245782     Monsieur                                Perret Thibaud
# 238150     Monsieur                                  Poma Florian
# 247233     Monsieur                                 Ramirez Lucas
# 216801       Madame                            Reiss Saskia Naomi
# 225452     Monsieur                                   Resin David
# 225691     Monsieur                             Rey Samuel Pierre
# 228149       Madame  Richard Lou Fortunée Valentine Yvonne Émilie
# 250362     Monsieur                        Rigori Valentin Joseph
# 247680     Monsieur                                    Soufi Raja
# 246532     Monsieur                         Vaucher Timoté Pascal
# 247891     Monsieur                                Weier Philippe
# 212826     Monsieur                               Willemin Xavier
# 237151     Monsieur                          Zbinden Boris Adrien
# 226652     Monsieur                         Zenhäusern Joey Kevin
#
#           Bachelor semester 1 Start year Bachelor semester 6 End year  \
# No Sciper
# 169569              2007-2008       2007           2009-2010     2010
# 179449              2007-2008       2007           2009-2010     2010
# 178553              2007-2008       2007           2009-2010     2010
# 178271              2007-2008       2007           2009-2010     2010
# 180731              2007-2008       2007           2009-2010     2010
# 171619              2007-2008       2007           2009-2010     2010
# 178656              2007-2008       2007           2009-2010     2010
# 178706              2007-2008       2007           2009-2010     2010
# 181121              2007-2008       2007           2009-2010     2010
# 180570              2007-2008       2007           2009-2010     2010
# 181248              2007-2008       2007           2009-2010     2010
# 178433              2007-2008       2007           2009-2010     2010
# 181298              2007-2008       2007           2009-2010     2010
# 181115              2007-2008       2007           2009-2010     2010
# 180094              2007-2008       2007           2009-2010     2010
# 181017              2007-2008       2007           2009-2010     2010
# 179194              2007-2008       2007           2009-2010     2010
# 179988              2007-2008       2007           2009-2010     2010
# 180959              2007-2008       2007           2009-2010     2010
# 171195              2007-2008       2007           2009-2010     2010
# 178948              2007-2008       2007           2009-2010     2010
# 180241              2007-2008       2007           2009-2010     2010
# 180854              2007-2008       2007           2009-2010     2010
# 178682              2007-2008       2007           2009-2010     2010
# 184772              2008-2009       2008           2010-2011     2011
# 179406              2007-2008       2007           2010-2011     2011
# 179428              2007-2008       2007           2010-2011     2011
# 179426              2007-2008       2007           2010-2011     2011
# 185949              2008-2009       2008           2010-2011     2011
# 179157              2007-2008       2007           2010-2011     2011
# ...                       ...        ...                 ...      ...
# 223344              2012-2013       2012           2015-2016     2016
# 228275              2012-2013       2012           2015-2016     2016
# 223892              2012-2013       2012           2015-2016     2016
# 217098              2011-2012       2011           2015-2016     2016
# 214293              2011-2012       2011           2015-2016     2016
# 246663              2014-2015       2014           2016-2017     2017
# 237482              2013-2014       2013           2015-2016     2016
# 213287              2011-2012       2011           2015-2016     2016
# 245511              2014-2015       2014           2016-2017     2017
# 227359              2012-2013       2012           2015-2016     2016
# 250703              2014-2015       2014           2016-2017     2017
# 224297              2013-2014       2013           2015-2016     2016
# 245512              2014-2015       2014           2016-2017     2017
# 247855              2014-2015       2014           2016-2017     2017
# 227311              2013-2014       2013           2016-2017     2017
# 204324              2011-2012       2011           2015-2016     2016
# 245782              2014-2015       2014           2016-2017     2017
# 238150              2013-2014       2013           2015-2016     2016
# 247233              2014-2015       2014           2016-2017     2017
# 216801              2011-2012       2011           2015-2016     2016
# 225452              2012-2013       2012           2016-2017     2017
# 225691              2013-2014       2013           2015-2016     2016
# 228149              2012-2013       2012           2015-2016     2016
# 250362              2014-2015       2014           2016-2017     2017
# 247680              2014-2015       2014           2016-2017     2017
# 246532              2014-2015       2014           2016-2017     2017
# 247891              2014-2015       2014           2016-2017     2017
# 212826              2011-2012       2011           2015-2016     2016
# 237151              2013-2014       2013           2015-2016     2016
# 226652              2012-2013       2012           2015-2016     2016
#
#           Bachelor semester 5 Bachelor 5 end year  Extra semester  \
# No Sciper
# 169569              2009-2010                2010             0.0
# 179449              2009-2010                2010             0.0
# 178553              2009-2010                2010             0.0
# 178271              2009-2010                2010             0.0
# 180731              2009-2010                2010             0.0
# 171619              2009-2010                2010             0.0
# 178656              2009-2010                2010             0.0
# 178706              2009-2010                2010             0.0
# 181121              2009-2010                2010             0.0
# 180570              2009-2010                2010             0.0
# 181248              2009-2010                2010             0.0
# 178433              2009-2010                2010             0.0
# 181298              2009-2010                2010             0.0
# 181115              2009-2010                2010             0.0
# 180094              2009-2010                2010             0.0
# 181017              2009-2010                2010             0.0
# 179194              2009-2010                2010             0.0
# 179988              2009-2010                2010             0.0
# 180959              2009-2010                2010             0.0
# 171195              2009-2010                2010             0.0
# 178948              2009-2010                2010             0.0
# 180241              2009-2010                2010             0.0
# 180854              2009-2010                2010             0.0
# 178682              2009-2010                2010             0.0
# 184772              2010-2011                2011             0.0
# 179406              2010-2011                2011             0.0
# 179428              2010-2011                2011             0.0
# 179426              2010-2011                2011             0.0
# 185949              2010-2011                2011             0.0
# 179157              2010-2011                2011             0.0
# ...                       ...                 ...             ...
# 223344              2016-2017                2017             0.5
# 228275              2016-2017                2017             0.5
# 223892              2016-2017                2017             0.5
# 217098              2016-2017                2017             0.5
# 214293              2016-2017                2017             0.5
# 246663              2016-2017                2017             0.0
# 237482              2016-2017                2017             0.5
# 213287              2016-2017                2017             0.5
# 245511              2016-2017                2017             0.0
# 227359              2016-2017                2017             0.5
# 250703              2016-2017                2017             0.0
# 224297              2016-2017                2017             0.5
# 245512              2016-2017                2017             0.0
# 247855              2016-2017                2017             0.0
# 227311              2016-2017                2017             0.0
# 204324              2016-2017                2017             0.5
# 245782              2016-2017                2017             0.0
# 238150              2016-2017                2017             0.5
# 247233              2016-2017                2017             0.0
# 216801              2016-2017                2017             0.5
# 225452              2016-2017                2017             0.0
# 225691              2016-2017                2017             0.5
# 228149              2016-2017                2017             0.5
# 250362              2016-2017                2017             0.0
# 247680              2016-2017                2017             0.0
# 246532              2016-2017                2017             0.0
# 247891              2016-2017                2017             0.0
# 212826              2016-2017                2017             0.5
# 237151              2016-2017                2017             0.5
# 226652              2016-2017                2017             0.5
#
#            Stay in years
# No Sciper
# 169569               3.0
# 179449               3.0
# 178553               3.0
# 178271               3.0
# 180731               3.0
# 171619               3.0
# 178656               3.0
# 178706               3.0
# 181121               3.0
# 180570               3.0
# 181248               3.0
# 178433               3.0
# 181298               3.0
# 181115               3.0
# 180094               3.0
# 181017               3.0
# 179194               3.0
# 179988               3.0
# 180959               3.0
# 171195               3.0
# 178948               3.0
# 180241               3.0
# 180854               3.0
# 178682               3.0
# 184772               3.0
# 179406               4.0
# 179428               4.0
# 179426               4.0
# 185949               3.0
# 179157               4.0
# ...                  ...
# 223344               4.5
# 228275               4.5
# 223892               4.5
# 217098               5.5
# 214293               5.5
# 246663               3.0
# 237482               3.5
# 213287               5.5
# 245511               3.0
# 227359               4.5
# 250703               3.0
# 224297               3.5
# 245512               3.0
# 247855               3.0
# 227311               4.0
# 204324               5.5
# 245782               3.0
# 238150               3.5
# 247233               3.0
# 216801               5.5
# 225452               5.0
# 225691               3.5
# 228149               4.5
# 250362               3.0
# 247680               3.0
# 246532               3.0
# 247891               3.0
# 212826               5.5
# 237151               3.5
# 226652               4.5
#
# [397 rows x 10 columns]

# %%
all_bachelor['Stay in months'] = all_bachelor['Stay in years']*12
all_bachelor.head()
# Out:
#            Civilité              Nom Prénom Bachelor semester 1 Start year  \
# No Sciper
# 169569     Monsieur       Arévalo Christian           2007-2008       2007
# 179449     Monsieur   Bindschaedler Vincent           2007-2008       2007
# 178553     Monsieur      Bloch Marc-Olivier           2007-2008       2007
# 178271     Monsieur  Boéchat Marc-Alexandre           2007-2008       2007
# 180731     Monsieur    Bricola Jean-Charles           2007-2008       2007
#
#           Bachelor semester 6 End year Bachelor semester 5  \
# No Sciper
# 169569              2009-2010     2010           2009-2010
# 179449              2009-2010     2010           2009-2010
# 178553              2009-2010     2010           2009-2010
# 178271              2009-2010     2010           2009-2010
# 180731              2009-2010     2010           2009-2010
#
#           Bachelor 5 end year  Extra semester  Stay in years  Stay in months
# No Sciper
# 169569                   2010             0.0            3.0            36.0
# 179449                   2010             0.0            3.0            36.0
# 178553                   2010             0.0            3.0            36.0
# 178271                   2010             0.0            3.0            36.0
# 180731                   2010             0.0            3.0            36.0

# %%
# for analysis we need the sex and duration in months
all_bachelor = all_bachelor[['Civilité','Stay in months']]

# %%
all_bachelor.groupby(['Civilité']).mean()
# Out:
#           Stay in months
# Civilité
# Madame         40.758621
# Monsieur       42.880435

# %%
all_bachelor.describe()
# Out:
#        Stay in months
# count      397.000000
# mean        42.725441
# std          9.372089
# min         36.000000
# 25%         36.000000
# 50%         36.000000
# 75%         48.000000
# max         84.000000

# %% [markdown]
# As we need to see if the difference in average statistically significant for the months spent in bachelor in EPFL between man and woman, we need to so Two-Sample T-Test. Let us take a significant level of 5%

# %%
man = []
woman = []
for i in range(len(all_bachelor)) :
    if all_bachelor['Civilité'][i] == 'Monsieur':
        man.append(all_bachelor['Stay in months'][i])
    else :
        woman.append(all_bachelor['Stay in months'][i])
        

stats.ttest_ind(a= man,
                b= woman,
                equal_var=False)
# Out:
# Ttest_indResult(statistic=1.3437005678090845, pvalue=0.18785555340784144)

# %% [markdown]
# We can see that the pvalue is greater than our significant level. hence we cannot reject the hypothesis that the average numbers of months spent in bachelor at EPFL for a man or a woman isn't equal (it can be the same average)

# %% [markdown]
# ### Exercise 2 : Master

# %% [markdown]
# The IS-Academia data for master students is more complicated. We take all students who finished M1 and M2 at EPFL into account. We consider first entry in M1 as start year and we double-check whether students registered for M1 again after completing the

# %% [markdown]
# For masters we modify the toframe method to include more columns as now we are interested in specialisations and minors.

# %%
def masterstoframe(soup):
    # create headers for the data frame
    headers = soup.find_all('th')
    H = [h.text.strip() for h in headers]

    #remove the extra column with the table name "Informatique ..." and the repetitions of the header
    del H[0] 
    del H[11:len(H)]

    # find all rows
    datatable_rows = soup.find_all('tr')

    # iterate the data in td cells to an array
    # iterate the year data from the header to an year array
    data = []
    year = []
    for row in datatable_rows:
        # if row is a header and has a tag font (information about the table: section, period and year)
        if (row.th != None and row.th.font):
            # select the year from the header 
            actual_year = row.th.font.contents[0].split(",")[1]
        # if row is not a header find all tds    
        elif (row.th == None and int(actual_year.split("-")[0])>=2007): 
            td = row.find_all('td')      
            rowvals = {}
            for i in range(len(H)):
                year.append(actual_year)
                rowvals[H[i]] = td[i].get_text()
                data.append(rowvals)
               
    df = pd.DataFrame(data, columns=H)
    
    # keep interesting columns
    df = df[['No Sciper', 'Civilité', 'Nom Prénom', 'Spécialisation', 'Mineur']]
    
    # add year information
    df['year'] = year
    
    # drop the duplicates of the data frame
    df = df.drop_duplicates()

    # set the student number as the Index
    df = df.set_index(['No Sciper'])
    
    return df

# %%
# take all master semester 1 registrations and put them in a dataframe
master1 = masterstoframe(tosoup(encode['Master semestre 1']))
# add master level column
master1['Level'] = 'MA1'


# take all master semester 2 registrations and put them in a dataframe
master2 = masterstoframe(tosoup(encode['Master semestre 2']))
#add master level column
master2['Level'] = 'MA2'



# take all master semester 3 registrations and put them in a dataframe
master3 = masterstoframe(tosoup(encode['Master semestre 3']))
#add master level column
master3['Level'] = 'MA3'

# take all master autumn and spring registrations and put them in two dataframes
autumn_project = masterstoframe(tosoup(encode['Projet Master automne']))
autumn_project['Level'] = 'Autumn Project'
spring_project = masterstoframe(tosoup(encode['Projet Master printemps']))
spring_project['Level'] = 'Semester Project'

# concatenate all masters semesters and projects
master123 = pd.concat([master1,master2,master3, autumn_project, spring_project
                       
# sort by index to get every master semester and project done by each student
master123.index = master123.sort_index()

# show the obtained dataFrame
master123
# Out:
#   File "<ipython-input-44-e24d8b085c40>", line 30
#     master123.index = master123.sort_index()
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# Now that we have a dataFrame describing the number of semesters of each student with the number of semester done ordered, we can count the duration of each student in year at EPFL.
# It is important to specify that for the masters, we don't need to take into account the year of begging and ending of each person as even if they stopped courses in between, they are registered as in 'congé' or  'stage'.
# We also didn't count people who has done only one semester as they probably didn't get their master at EPFL.

# %%
# number of semesters spent by each student in months by Sciper numbers
master123.index.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-17a8821bec99> in <module>()
#       1 # number of semesters spent by each student in months by Sciper numbers
# ----> 2 master123.index.value_counts()
#
# NameError: name 'master123' is not defined

# %%
# copy the previous merged master frame
semesters_frame = master123.copy()

# get the number of semesters done by each student
stay = master123.index.value_counts()

# just take the first No Sciper of each student (in other terms drop the duplicates by index)
semesters_frame = semesters_frame.groupby(semesters_frame.index).first()

# create a new column in the frame with the number of semesters done by each student
semesters_frame['stay_in_months'] = stay.values

# drop unecessary columns for our analysis
semesters_frame.drop(['year', 'Level'], axis = 1, inplace = True)

# remove student that were registered in one semester or less
semesters_frame = semesters_frame[semesters_frame.stay_in_months >= 2]

# convert the stay from semesters to months
semesters_frame.stay_in_months = semesters_frame.stay_in_months * 6

# show the frame
semesters_frame

# %% [markdown]
# We want to remove students that has specialisation but are registered since less than 3 semesters i.e still doing their masters.

# %%
# create a new dataFrame to get indices to remove as explained above 
semesters_frame2 = semesters_frame.copy()
# take intersection of the two sets (<18 and have spécialisation)
semesters_frame2 = semesters_frame2[semesters_frame2.stay_in_months < 18]
semesters_frame2 = semesters_frame2[semesters_frame2.Spécialisation != '']
# indices to remove as a List
to_remove = semesters_frame2.index.values.tolist()
# remove thoses indices from our initial dataFrame
semesters_frame = semesters_frame.drop(to_remove, axis = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-76ca4016bf89> in <module>()
#       1 # create a new dataFrame to get indices to remove as explained above
# ----> 2 semesters_frame2 = semesters_frame.copy()
#       3 # take intersection of the two sets (<18 and have spécialisation)
#       4 semesters_frame2 = semesters_frame2[semesters_frame2.stay_in_months < 18]
#       5 semesters_frame2 = semesters_frame2[semesters_frame2.Spécialisation != '']
#
# NameError: name 'semesters_frame' is not defined

# %%
semesters_frame.stay_in_months.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-8cca23c57c10> in <module>()
# ----> 1 semesters_frame.stay_in_months.describe()
#
# NameError: name 'semesters_frame' is not defined

# %%
# take only the people who has Spécialisation from the data Frame
semester_frame_spec = semesters_frame[semesters_frame['Spécialisation'] != '']

# do the groupby by spécialisation
semester_frame_spec.groupby('Spécialisation').mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-6997ac7853bc> in <module>()
#       1 # take only the people who has Spécialisation from the data Frame
# ----> 2 semester_frame_spec = semesters_frame[semesters_frame['Spécialisation'] != '']
#       3
#       4 # do the groupby by spécialisation
#       5 semester_frame_spec.groupby('Spécialisation').mean()
#
# NameError: name 'semesters_frame' is not defined

# %% [markdown]
# We can see from the resutls that the new specializations have an average length of 18 months only (i.e the minimum) because they just have been launched. Those are the people in MA3 that started their master with no specialization but took the courses required to have it and asked for it as soon as it has been launched.

# %% [markdown]
# ### Statistical test :

# %% [markdown]
# As we need to see now if there is any specialization for which the difference in average is statistically significant compared to the general average, we need to do a one One-Sample T-Test as it checks whether a sample mean (spécialisation mean) differs from the population mean (average stay in Master Epfl).

# %%
# we loop on all spécialisation
for spec in semester_frame_spec['Spécialisation'].drop_duplicates() :
    # get the months spent by each student of the spec spécialisation to compute the mean
    data = np.array(semester_frame_spec[semester_frame_spec.Spécialisation == spec]['stay_in_months'])
    # if we have a really small number of samples we cannot rely on the statistic test
    if (len(data) < 5) :
        print("we cannot conclude for this spécialisation as we have less than five samples for the " + str(spec) + " spécialisation")
        continue
    # all students average stay at EPFL
    mean_spec = data.mean()
    # Spécialisation students average stay at EPFL
    mean_all = semesters_frame.stay_in_months.mean()
    # call the stats one function and get the p_value
    t, p = stats.ttest_1samp(mean_spec, mean_all)
    # if the p_value is less than 0.05 we reject at 95% level of confidence
    if (p < 0.05) :
        print("as the p value is equal to " + str(p) + " which is less than 0.05 we can say that we reject the hypothesis that the stay of a Spécialisation " + str(spec) + " student average duration is equal to the average stay of a general student at level 95%")
        # if the p_value is higher than 0.05 we accept at 95% level of confidence
    else : 
        print("as the p value is equel to " + str(p) + " which is higher than 0.05 we can say that we cannot reject the hypothesis that the Spécialisation " + str(spec) + "student average duration is equal to the average stay of a general student at level 95% (they can be equal)")

# %% [markdown]
# ### Exercise 3 :

# %%
semester_frame_spec = semester_frame_spec['Civilité', 'stay_in_months']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0196c5dd547e> in <module>()
# ----> 1 semester_frame_spec['Civilité', 'stay_in_months']
#
# NameError: name 'semester_frame_spec' is not defined
